# %%
# !pip install twint
# !pip3 install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# ...
#      |████████████████████████████████| 1.3 MB 6.2 MB/s
# ...
#      |████████████████████████████████| 263 kB 51.3 MB/s
# ...
#      |████████████████████████████████| 356 kB 45.5 MB/s
# ...
#      |████████████████████████████████| 291 kB 26.8 MB/s
# ...
#      |████████████████████████████████| 142 kB 58.0 MB/s
# ...
#      |████████████████████████████████| 294 kB 55.3 MB/s
# ...
#   Created wheel for twint: filename=twint-2.1.20-py3-none-any.whl size=33930 sha256=7df2e05f962e7c8d33ea9569f0648a1f3377f6cb61ea874dcbc262f2e563e939
#   Stored in directory: /root/.cache/pip/wheels/44/fc/77/99887a36b5c265a87516158858697d1a0b8f32c4d4dbddbb24
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13503 sha256=b4c6165783707991ae5c02fa6a9525d8dc89a3b9963485017e0b28c4308b87aa
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
# ...

# %%
import twint
from os import mkdir, path
import pandas as pd
import numpy as np
import nest_asyncio
from glob import glob


pd.set_option("display.max_columns", 50)

# %%
from datetime import date, datetime, timedelta
from string import ascii_letters, digits
nest_asyncio.apply()

# %%
def clean_name(dirname):
    valid = set(ascii_letters + digits)
    return ''.join(a for a in dirname if a in valid)

# %%
def twint_search(hashtag, since, until, json_name):
    c = twint.Config()
    c.Limit = 5000
    c.Search = hashtag
    c.Store_json = True
    c.Output = json_name
    c.Pandas = True
    c.Verified = True
    c.Since = since
    c.Until = until
    try:
        twint.run.Search(c)    
    except (KeyboardInterrupt, SystemExit):
        raise
    except:
        print("Problem with %s." % since)

# %%
def twint_loop(searchterm, since, until):

    dirname = clean_name(searchterm)
    try:
    # Create target Directory
        mkdir(dirname)
        print("Directory" , dirname ,  "Created ")
    except FileExistsError:
        print("Directory" , dirname ,  "already exists")

    daterange = pd.date_range(since, until)

    for start_date in daterange:

        since = start_date.strftime("%Y-%m-%d")
        until = (start_date + timedelta(days=1)).strftime("%Y-%m-%d")

        json_name = '%s.json' % since
        json_name = path.join(dirname, json_name)

        print('Getting %s ' % since )
        twint_search(searchterm, since, until, json_name)

# %%
twint_loop('blacklivesmatter', '2020-05-24', '2020-05-26')
# Out:
# Directory blacklivesmatter already exists
# Getting 2020-05-24
# 1264706728983236608 2020-05-25 01:55:55 +0200 <pcrb1985> That's not racist at all. 😤😤🤔🤔 #BlackTwitter #BlackLivesMatter #BlacksForTrump
# 1264705108140531712 2020-05-25 01:49:29 +0200 <carbonatedthoug> @NikkiHaley The idea of #foxnews and #gop pretending not to be racism this weekend is a joke! #BlackLivesMatter Yes Biden said something stupid. But he is running against #trump and his #nazi loving #WhiteHouse! #GoJoe will pick smart people and has already apologized for his error!
# 1264704809724260352 2020-05-25 01:48:18 +0200 <adtscentral> Periodt! #COVID19 #capitalism_is_the_virus #capitalismaintshitwithoutthepeople #blacklivesmatter #DividedWeFall
# ...

# %%
#glob(path.join('blacklivesmatter','*.json'))
file_names = glob(path.join('blacklivesmatter','*.json'))
dfs = [pd.read_json(fn, lines = True) for fn in file_names]
blm_2020 = pd.concat(dfs)

# %%
blm_2020
# Out:
#                        id      conversation_id  \
# 0     1332836586225086466  1332836586225086464
# 1     1332836537592147968  1332836537592147968
# 2     1332836533808869382  1332836533808869376
# 3     1332836495250644993  1332823904671428608
# 4     1332836037740142592  1332836037740142592
# ...                   ...                  ...
# 5746  1365814283544776705  1365814283544776704
# 5747  1365814159246581761  1365814159246581760
# 5748  1365814158520967171  1365814158520967168
# 5749  1365814155295473665  1365814155295473664
# 5750  1365813976483786754  1365813976483786752
#
#                                              created_at       date      time  \
# 0     2020-11-29 00:59:39 ora solare Europa occidentale 2020-11-29  00:59:39
# 1     2020-11-29 00:59:28 ora solare Europa occidentale 2020-11-29  00:59:28
# 2     2020-11-29 00:59:27 ora solare Europa occidentale 2020-11-29  00:59:27
# 3     2020-11-29 00:59:18 ora solare Europa occidentale 2020-11-29  00:59:18
# ...

# %%
df_BLM_eng = blm_2020[blm_2020["language"] == "en"]

# %%
df_BLM_eng
# Out:
#                        id      conversation_id  \
# 0     1332836586225086466  1332836586225086464
# 1     1332836537592147968  1332836537592147968
# 2     1332836533808869382  1332836533808869376
# 3     1332836495250644993  1332823904671428608
# 4     1332836037740142592  1332836037740142592
# ...                   ...                  ...
# 5746  1365814283544776705  1365814283544776704
# 5747  1365814159246581761  1365814159246581760
# 5748  1365814158520967171  1365814158520967168
# 5749  1365814155295473665  1365814155295473664
# 5750  1365813976483786754  1365813976483786752
#
#                                              created_at       date      time  \
# 0     2020-11-29 00:59:39 ora solare Europa occidentale 2020-11-29  00:59:39
# 1     2020-11-29 00:59:28 ora solare Europa occidentale 2020-11-29  00:59:28
# 2     2020-11-29 00:59:27 ora solare Europa occidentale 2020-11-29  00:59:27
# 3     2020-11-29 00:59:18 ora solare Europa occidentale 2020-11-29  00:59:18
# ...

# %%
df_BLM_eng.to_csv("data/quarta_parte.csv")

# %%
df_BLM_eng = blm_prova_2020[blm_prova_2020["language"] == "en"]

# %%
df_BLM_eng
# Out:
#                        id      conversation_id  \
# 0     1265432521359196161  1265432521359196160
# 1     1265432520386056193  1265380812838617088
# 2     1265432513721315334  1265432513721315328
# 4     1265432497736888323  1265430326064476160
# 5     1265432497027985409  1265432497027985408
# ...                   ...                  ...
# 4994  1265413582289854464  1265413582289854464
# 4995  1265413580058497025  1265413580058497024
# 4996  1265413577474793478  1265413577474793472
# 4997  1265413574442262535  1265371269018587136
# 4998  1265413573372755971  1265359374010273792
#
#                                              created_at       date      time  \
# 0     2020-05-27 01:59:58 ora legale Europa occidentale 2020-05-27  01:59:58
# 1     2020-05-27 01:59:58 ora legale Europa occidentale 2020-05-27  01:59:58
# 2     2020-05-27 01:59:56 ora legale Europa occidentale 2020-05-27  01:59:56
# 4     2020-05-27 01:59:52 ora legale Europa occidentale 2020-05-27  01:59:52
# ...
